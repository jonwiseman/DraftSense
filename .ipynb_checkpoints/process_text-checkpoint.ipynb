# %%
import json
import re
import pickle

# %%
with open('/home/jon/Desktop/thesis/2010/2010_processed.json', 'r') as f:
    data = json.load(f)

# %%
for article in data:
    if has_date(article):
        article['title'] = clean_text(article['title'])
        article['content'] = clean_text(article['content'])
    
        article['title'] = clean_team_names(article['title'], full_team_names)
        article['content'] = clean_team_names(article['content'], full_team_names)
    else:
        data.remove(article)

# %%
len(data)
# Out:
# 6651

# %%
def clean_text(text):
    if text is None:
        return text
    cleaned = re.sub(r'\s\s+', ' ', text)
    cleaned = re.sub(r'\n', '', cleaned)
    cleaned = re.sub(r'\s([,.?!;)])', r'\1', cleaned)
    cleaned = re.sub(r'No. (\d)', r'number \1', cleaned)
    return cleaned

# %%
def clean_team_names(text, long_names):
    if text is None:
        return text
    
    cleaned_text = text
    for name in long_names:
        comp = name.split(' ')
        team = comp[-1]
        city = comp[0]
        if len(comp) == 3:
            city = ' '.join(comp[:-1])
            
        cleaned_text = re.sub(name, team, cleaned_text)
        cleaned_text = re.sub(city, team, cleaned_text)
    return cleaned_text

# %%
def has_date(article):
    if article['date'] is None:
        return False
    
    return True

# %%
year = 2010
corpus = pd.read_json('/home/jon/Desktop/thesis/2010/2010.json')
teams = pickle.load(open(f'/home/jon/Desktop/thesis/2010/teams_aliases.p', 'rb'))
players_to_teams = pickle.load(open('/home/jon/Desktop/thesis/2010/players_teams_mapping.p', 'rb'))

players = list(players_to_teams.keys())

# %%
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
corpus['content']
# Out:
# 0       Each Monday, Matt Williamson from Scouts Inc. ...
# 1       Last Wednesday, Football Outsiders began its P...
# 2       A year ago, it was pretty easy to figure out t...
# 3       I wasn't in Indianapolis for the NFL scouting ...
# 4       There were 256 players selected in the seven r...
# 5       PITTSBURGH --  The  Pittsburgh Penguins  still...
# 6       JACKSONVILLE, Fla. --  The  Jacksonville Jagua...
# 7       NEW YORK --  Tennessee Titans  backup quarterb...
# 8
# 9       INDIANAPOLIS --   Peyton Manning  could still ...
# 10      New Jersey rock star Jon Bon Jovi has been in ...
# 11      Despite being touted like a cruise on the Star...
# 12      ARLINGTON, Texas --   Green Bay Packers  corne...
# 13      ARLINGTON, Texas -- Three months ago,  Howard ...
# 14      Winning a Super Bowl is a rich enough experien...
# 15      DALLAS -- When coaches, players, scouts and an...
# 16      Did you miss a week of Monday Matchup Madness?...
# ...

# %%
import neuralcoref
neuralcoref.add_to_pipe(nlp)

# %%
text = corpus.iloc[150]['content']

# %%
text
# Out:
# "IRVING, Texas -- The  Dallas Cowboys  will lose their starting left guard for the second time this season. Kyle Kosier  will miss two to three weeks with a strained right Achilles tendon. Kosier suffered the injury in the first half of Sunday's loss to the  Minnesota Vikings  and missed the entire second half. Montrae Holland  replaced Kosier in the starting lineup Sunday and most likely will start Monday's game against the  New York Giants . Kosier missed the season opener as he recovered from a sprained medial collateral ligament he suffered in training camp. The Cowboys' offensive line has been banged up this season. It's original starting lineup has been together the past four games, but Kosier couldn't finish two games due to injuries and starting right guard  Leonard Davis  was benched in the loss to the  Tennessee Titans . Holland suffered an eye injury in the Texans' game after replacing Davis, allowing Davis to return. Also, quarterback  Tony Romo  has a bruised left thumb 
# ...

# %%
doc = nlp(corpus.iloc[150]['content'])

# %%
from spacy.symbols import nsubj, VERB
verbs = set()

for possible_subject in doc:
    if possible_subject.dep == nsubj:
        print(possible_subject)
# Out:
# Cowboys
# Kosier
# Kosier
# Holland
# Kosier
# he
# he
# It
# lineup
# Kosier
# Holland
# Davis
# Romo
# receiver
# he
# it
# Watkins

# %%
displacy.render(doc)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ea8fd91adb384f41818dfa1fbdb4c150-0" class="displacy" width="39250" height="1274.5" direction="ltr" style="max-width: none; height: 1274.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">IRVING,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Texas --</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">The</tspan>
# ...

# %%
root = [token for token in doc if token.head == token][4]

# %%
root.ent_iob_
# Out:
# 'O'

# %%
root.left_edge
# Out:
# Montrae

# %%
root.right_edge
# Out:
# .

# %%
doc[20]
# Out:
# season

# %%
sentence = doc[doc[20].left_edge.i: doc[20].right_edge.i+1]

# %%
sentence
# Out:
# this season

# %%
for sent in doc.sents:
    print(sent.text)
# Out:
# IRVING, Texas --
# The  Dallas Cowboys  will lose The  Dallas Cowboys
# starting left guard for the second time this season.
# Kyle Kosier  will miss two to three weeks with a strained right Achilles tendon.
# Kyle Kosier   suffered the injury in the first half of Sunday's loss to the  Minnesota Vikings  and missed the entire second half.
# Montrae Holland  replaced Kyle Kosier   in the starting lineup Sunday and most likely will start Monday's game against the  New York Giants .
# Kyle Kosier   missed the season opener as Kyle Kosier   recovered from a sprained medial collateral ligament Kyle Kosier   suffered in training camp.
# The  Dallas Cowboys   offensive line has been banged up this season.
# The Cowboys' offensive line's original starting lineup has been together the past four games, but Kyle Kosier   couldn't finish two games due to injuries and starting right guard
# Leonard Davis  was benched in the loss to the  Tennessee Titans .
# ...

# %%
doc._.coref_clusters
# Out:
# [The  Dallas Cowboys  : [The  Dallas Cowboys  , their, The Cowboys', the Cowboys],
#  this season: [this season, this season],
#  Kyle Kosier  : [Kyle Kosier  , Kosier, Kosier, Kosier, he, he, Kosier],
#  Sunday: [Sunday, Sunday],
#  Montrae Holland  : [Montrae Holland  , Holland],
#  Monday: [Monday, Monday],
#  The Cowboys' offensive line: [The Cowboys' offensive line, It],
#  Leonard Davis  : [Leonard Davis  , Davis],
#  quarterback  : [quarterback  , it],
#  Tony Romo  : [Tony Romo  , his, he, him],
#  Wide receiver  Dez Bryant  : [Wide receiver  Dez Bryant  , it]]

# %%
from spacy import displacy

# %%
displacy.render(doc)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="75691a861c974a7699eef966766f2200-0" class="displacy" width="39250" height="1274.5" direction="ltr" style="max-width: none; height: 1274.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">IRVING,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Texas --</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">The</tspan>
# ...

# %%
doc = nlp('Kyle Irving said he is a lil bitch')

# %%
displacy.render(doc)
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6779bec48c1446528339d29b430626d6-0" class="displacy" width="1450" height="399.5" direction="ltr" style="max-width: none; height: 399.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Kyle</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Irving</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="309.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">said</tspan>
# ...

# %%
type(list(doc.sents)[0])
# Out:
# spacy.tokens.span.Span

# %%
test = doc._.coref_resolved

# %%
test
# Out:
# "IRVING, Texas -- The  Dallas Cowboys  will lose The  Dallas Cowboys   starting left guard for the second time this season. Kyle Kosier  will miss two to three weeks with a strained right Achilles tendon. Kyle Kosier   suffered the injury in the first half of Sunday's loss to the  Minnesota Vikings  and missed the entire second half. Montrae Holland  replaced Kyle Kosier   in the starting lineup Sunday and most likely will start Monday's game against the  New York Giants . Kyle Kosier   missed the season opener as Kyle Kosier   recovered from a sprained medial collateral ligament Kyle Kosier   suffered in training camp. The  Dallas Cowboys   offensive line has been banged up this season. The Cowboys' offensive line's original starting lineup has been together the past four games, but Kyle Kosier   couldn't finish two games due to injuries and starting right guard  Leonard Davis  was benched in the loss to the  Tennessee Titans . Montrae Holland   suffered an eye injury in the Texans'
# ...

# %%
doc = nlp(test)

# %%
for ent in doc.ents:
    print(ent.text, ent.start_char, ent.end_char, ent.label_)
# Out:
# IRVING 0 6 ORG
# Texas 8 13 GPE
# Dallas 22 28 GPE
# Cowboys 29 36 ORG
# Dallas 53 59 GPE
# Cowboys 60 67 ORG
# second 98 104 ORDINAL
# this season 110 121 DATE
# Kyle Kosier 123 134 PERSON
# two to three weeks 146 164 DATE
# Achilles 187 195 PERSON
# Kyle Kosier 204 215 PERSON
# the first half of Sunday's 241 267 DATE
# Minnesota Vikings 281 298 NORP
# the entire second half 311 333 DATE
# Montrae Holland 335 350 GPE
# Kyle Kosier 361 372 PERSON
# Sunday 398 404 DATE
# Monday 432 438 DATE
# New York Giants 459 474 ORG
# Kyle Kosier 477 488 PERSON
# the season 498 508 DATE
# Kyle Kosier 519 530 PERSON
# Kyle Kosier 586 597 PERSON
# Dallas 632 638 GPE
# Cowboys 639 646 ORG
# this season 683 694 DATE
# Cowboys 700 707 ORG
# four 778 782 CARDINAL
# Kyle Kosier 794 805 PERSON
# two 824 827 CARDINAL
# Leonard Davis 876 889 PERSON
# Tennessee Titans 923 939 ORG
# Montrae Holland 942 957 GPE
# Texans 990 996 NORP
# Davis 1019 1024 PERSON
# Leonard Davis 1035 1048 PERSON
# ...

# %%
print(doc)
# Out:
# IRVING, Texas -- The  Dallas Cowboys  will lose The  Dallas Cowboys   starting left guard for the second time this season. Kyle Kosier  will miss two to three weeks with a strained right Achilles tendon. Kyle Kosier   suffered the injury in the first half of Sunday's loss to the  Minnesota Vikings  and missed the entire second half. Montrae Holland  replaced Kyle Kosier   in the starting lineup Sunday and most likely will start Monday's game against the  New York Giants . Kyle Kosier   missed the season opener as Kyle Kosier   recovered from a sprained medial collateral ligament Kyle Kosier   suffered in training camp. The  Dallas Cowboys   offensive line has been banged up this season. The Cowboys' offensive line's original starting lineup has been together the past four games, but Kyle Kosier   couldn't finish two games due to injuries and starting right guard  Leonard Davis  was benched in the loss to the  Tennessee Titans . Montrae Holland   suffered an eye injury in the Texans' 
# ...

# %%
doc.ents[0].label_
# Out:
# 'ORG'

# %%
doc.noun_chunks

# %%
doc = nlp("Markus is great at fucking in the ass, but he is better at taking it.  He needs to work at receiving as well as giving.")

# %%
for sent in doc.sents:
    print(sent)
# Out:
# Markus is great at fucking in the ass, but he is better at taking it.
# He needs to work at receiving as well as giving.

# %%
doc._.coref_clusters
# Out:
# [Markus: [Markus, he, He]]

# %%
doc = nlp(doc._.coref_resolved
# Out:
# 'Markus is great at fucking in the ass, but Markus is better at taking it.  Markus needs to work at receiving as well as giving.'
